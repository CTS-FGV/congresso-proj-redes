# %%
import pandas as pd
import sqlalchemy
import imp

utils = imp.load_source('utils','../utils.py')

# %matplotlib inline  
# %pylab inline
pylab.rcParams['figure.figsize'] = (20,12)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
conn = utils.connect_sqlalchemy()

# %%
votacao_deputado = pd.read_sql_table('votacao_deputado', conn, schema='a_camdep')

# %%
votacao_deputado.head(3)
# Out:
#    codproposicao tipo  numero   ano  codsessao         datavotacao  \
# 0        2141401  REQ    6711  2017      16241 2017-06-13 16:00:00
# 1        2141401  REQ    6711  2017      16241 2017-06-13 16:00:00
# 2        2141401  REQ    6711  2017      16241 2017-06-13 16:00:00
#
#    idecadastro            nome partido  uf       voto
# 0      74784.0  Luiza Erundina    PSOL  SP  Obstrução
# 1     152610.0   Roberto Alves     PRB  SP        Sim
# 2     141480.0  Lázaro Botelho      PP  TO        Sim

# %% [markdown]
# #### Generate proposal hash

# %%
votacao_unique = votacao_deputado.drop_duplicates(subset=['codproposicao', 'codsessao' ,'datavotacao'])[['codproposicao', 'codsessao' ,'datavotacao']]
votacao_unique['votacao_id'] = votacao_unique.apply(lambda x: hash(tuple(x)), axis = 1)
votacao_deputado = votacao_deputado.merge(votacao_unique, on=['codproposicao', 'codsessao' ,'datavotacao'])

# %% [markdown]
# #### Analisis of voting data

# %%
votacao_deputado.groupby(['voto']).count()['ano']
# Out:
# voto
# -             26829
# Abstenção      9638
# Art. 17        2628
# Branco            2
# Não          447814
# Obstrução     42221
# Sim          598431
# Name: ano, dtype: int64

# %% [markdown]
# We can see that those are the types of votes on the database
#
# - 'Sim' and 'Não' are Yes or No votes
#
# - 'Obstrução' means Obstruction
#
# - 'Abstenção' means Abstention
#
# - 'Art. 17' means Article 17 which refers to prohibts the President of the House from voting
#
# - 'Branco' means Blank vote, but it just appeared once, so it is certantly a mistake.
#
# - '-' corresponds to the absence of the congressman
#
# Since I am interested on congressman with the same behaviour that will form edges on the graph, it seems reasonable to delete the following vote types: 'Art. 17', 'Branco'.

# %%
votacao_deputado = votacao_deputado[(votacao_deputado['voto'] != 'Art. 17') &
                 (votacao_deputado['voto'] != 'Branco')]
votacao_deputado.groupby(['voto']).count()['ano']
# Out:
# voto
# -             26829
# Abstenção      9638
# Não          447814
# Obstrução     42221
# Sim          598431
# Name: ano, dtype: int64

# %%
votacoes = votacao_deputado.groupby(['voto']).count()['ano']
print(votacoes['Sim']/votacoes['Não'])
votacao_deputado.groupby(['voto']).count()['ano'].plot(kind='bar')
# Out:
# 1.33633830117

# %%
votacao_deputado_time = votacao_deputado.set_index('datavotacao')
votacao_deputado_temp = votacao_deputado_time.groupby(['votacao_id', 'voto']).count()['codproposicao'].to_frame()

# %%
def test(x):
    try:
        s = (x.query('voto == "Sim"'))['codproposicao'].values[0]
    except:
        s=0
    
    try:
        b = (x.query('voto == "Não"'))['codproposicao'].values[0]
    except:
        b=0
    
    try:
        o = (x.query('voto == "Obstrucao"'))['codproposicao'].values[0]
    except:
        o=0
    
    if (b == 0) & (o == 0):
        return None
    else:
        return(s/(b+o))
votacao_deputado_temp = votacao_deputado_temp.groupby(level=0).apply(test)

# %%
#votacao_deputado_temp = votacao_deputado_temp.to_frame()
votacao_deputado_temp = votacao_deputado_temp.rename(columns={0:'ratio'}).reset_index()

# %%
votacao_deputado[['votacao_id','datavotacao']].merge(votacao_deputado_temp, on=['votacao_id']).drop_duplicates(subset=['votacao_id'])
# Out:
#                   votacao_id         datavotacao      ratio
# 0       -2512477794936961724 2017-06-13 16:00:00   4.391304
# 511      -292492304224832082 2017-06-07 19:19:00  27.062500
# 1022     5265952184040537262 2017-06-06 17:01:00  10.034483
# 1533    -5632581466997594037 2017-05-31 22:24:00   7.460000
# 2043     3869707901958342912 2017-05-31 20:30:00  15.440000
# 2553     7121840597532450731 2017-05-31 19:45:00  14.464286
# 3063    -2550095503540420549 2017-05-24 16:24:00   0.058140
# 3573    -2059324947987393986 2017-05-24 13:04:00   0.030769
# 4082    -1129767783065668376 2017-05-24 00:12:00   4.500000
# 4592    -8764697772461359554 2017-05-23 21:34:00   0.070039
# 5102     8014101770088941722 2017-05-23 20:56:00   0.153257
# 5612      896094015370427006 2017-05-23 19:25:00   0.020979
# 6122    -3611963701868633368 2017-05-23 17:45:00   0.041667
# 6632     1674544380698202428 2017-05-17 19:23:00   0.019157
# 7143    -8998705348319715037 2017-05-16 23:47:00   6.974359
# 7654     1581354307658424783 2017-05-16 23:09:00   0.066148
# 8165     4142762339634629188 2017-05-16 22:54:00  12.700000
# 8676    -1685012658298710485 2017-05-16 22:38:00   6.138889
# 9187      802149727214082232 2017-05-16 22:02:00   0.076336
# 9698     8095912410353284532 2017-05-16 20:53:00   0.120690
# 10209    5458938230719702252 2017-05-16 20:36:00  43.125000
# 10720     243078400781627183 2017-05-16 20:18:00   4.466667
# 11231   -7329590211213661978 2017-05-16 19:44:00  13.421053
# 11742   -2053704915623795503 2017-05-16 19:18:00   0.076305
# 12253   -4911551289720866992 2017-05-16 18:38:00   9.680000
# 12764   -9076150833926689870 2017-05-16 16:53:00  10.346154
# 13275    2141198797197764271 2017-05-16 15:05:00   0.070588
# 13786    2739719003092044940 2017-05-16 13:19:00   0.180124
# 14297   -5233153893671301267 2017-05-16 00:58:00   8.888889
# 14808       8153193226775690 2017-05-15 21:01:00   2.966292
# ...                      ...                 ...        ...
# 1116136  6491684233842233916 1991-12-15 14:05:00   0.246154
# 1116222  3461661597391921610 1991-12-15 13:39:00   2.947368
# 1116456  2915475786519347488 1991-12-12 19:56:00  17.400000
# 1116653  -962495042361967798 1991-12-12 18:00:00   6.086957
# 1116984 -7593601052301749723 1991-12-11 17:32:00  73.200000
# 1117363  8782644374921509544 1991-12-04 20:40:00  26.666667
# 1117452 -6614632030229281598 1991-12-04 18:16:00   2.894737
# 1117829  3823445136626511800 1991-12-03 20:40:00  13.750000
# 1118069 -2590862342046792704 1991-12-03 18:42:00   4.596491
# 1118392  6290551295572287136 1991-12-03 17:05:00   2.986301
# 1118690  3489689250168342142 1991-11-28 18:57:00   3.923077
# 1118888 -5388337797712433784 1991-11-07 17:05:00  18.600000
# 1119094 -3736741774523812432 1991-11-06 16:51:00  50.875000
# 1119514 -8034384380279369862 1991-10-29 17:15:00   3.593750
# 1119818  1754574227052141217 1991-10-23 18:41:00  21.300000
# 1120045  7775720884671556558 1991-10-08 18:11:00   4.722222
# 1120363  6626419696208988173 1991-09-19 13:55:00   0.515284
# 1120711  5292045926584012123 1991-09-17 18:03:00   2.680412
# 1121076 -2658116228692746384 1991-09-04 19:48:00   0.336735
# 1121342 -2665837457243290502 1991-09-04 17:35:00   0.578125
# 1121651  2797005747747483890 1991-08-28 20:10:00   1.256410
# 1122095 -7072675666898363633 1991-06-28 16:35:00   0.916667
# 1122395 -6823556903141752929 1991-06-28 14:18:00   0.709877
# 1122676 -8880623471065399358 1991-06-28 13:21:00   0.710843
# 1122966  6531652586086822256 1991-06-27 20:24:00   1.945736
# 1123350  -696208953304681363 1991-06-26 17:27:00   0.038462
# 1123683  -454699023505187934 1991-06-19 17:19:00   1.991935
# 1124061   799114006116672780 1991-05-22 18:05:00   1.543689
# 1124332 -5402501943197243382 1991-05-22 17:42:00   1.945055
# 1124607  2170227027560687827 1991-05-22 16:47:00   2.086538
#
# [3094 rows x 3 columns]
